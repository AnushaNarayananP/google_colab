# %% [markdown]
# <a href="https://colab.research.google.com/github/AnushaNarayananP/google_colab/blob/main/predictive_analytics_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to /root/nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud
from sklearn.feature_extraction.text import CountVectorizer

# %%
import time

import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import nltk

import io

import unicodedata

import numpy as np

import re

import string

from numpy import linalg

from nltk.sentiment.vader import SentimentIntensityAnalyzer

from nltk.tokenize import sent_tokenize, word_tokenize

from nltk.tokenize import PunktSentenceTokenizer

from nltk.tokenize import PunktSentenceTokenizer

from nltk.corpus import webtext

from nltk.stem.porter import PorterStemmer

from nltk.stem.wordnet import WordNetLemmatizer



with open('kindle.txt', encoding ='ISO-8859-2') as f:

    text = f.read()

# %%
 import string

# %%
sent_tokenizer = PunktSentenceTokenizer(text)

sents = sent_tokenizer.tokenize(text)


print(word_tokenize(text))

print(sent_tokenize(text))
# Out:
# ['FBPost', 'Label', '0', 'Drug', 'Runners', 'and', 'a', 'U.S', '.', 'Senator', 'have', 'something', 'to', 'do', 'with', 'the', 'Murder', 'http', ':', '//www.amazon.com/Circumstantial-Evidence-Getting-Florida-Bozarth-ebook/dp/B004FPZ452/ref=pd_rhf_p_t_1', 'The', 'State', 'Attorney', 'Knows', '...', 'NOW', 'So', 'Will', 'You', '.', 'GET', 'Ypur', 'Copy', 'TODAY', 'O', '1', "''", 'Heres', 'a', 'single', ',', 'to', 'add', ',', 'to', 'Kindle', '.', 'Just', 'read', 'this', '19th', 'century', 'story', ':', '``', "''", 'The', 'Ghost', 'of', 'Round', 'Island', "''", "''", '.', 'Its', 'about', 'a', 'man', '(', 'French/American', 'Indian', ')', 'and', 'his', 'dog', 'sled', 'transporting', 'a', 'woman', 'across', 'the', 'ice', ',', 'from', 'Mackinac', 'Island', 'to', 'Cheboygan', '-', 'and', 'the', 'ghost', 'that', '...', "''", 'O', '2', 'If', 'you', 'tire', 'of', 'Non-Fiction', '..', 'Check', 'out', 'http', ':', '//www.amazon.com/s/ref=nb_sb_noss', '?', 'url=search-alias', '%', '3Daps', '&', 'f
# ...

# %%
porter_stemmer = PorterStemmer()


nltk_tokens = nltk.word_tokenize(text)


for w in nltk_tokens:

    print ("Actual: % s Stem: % s" % (w, porter_stemmer.stem(w)))
# Out:
# Streaming output truncated to the last 5000 lines.
# Actual: thing Stem: thing
# Actual: ever Stem: ever
# Actual: invented Stem: invent
# Actual: ! Stem: !
# Actual: P Stem: p
# Actual: 823 Stem: 823
# Actual: '' Stem: ''
# Actual: Any Stem: ani
# Actual: chance Stem: chanc
# Actual: to Stem: to
# Actual: add Stem: add
# Actual: a Stem: a
# Actual: foreign Stem: foreign
# Actual: dictionary Stem: dictionari
# Actual: ? Stem: ?
# Actual: Im Stem: im
# Actual: reading Stem: read
# Actual: `` Stem: ``
# Actual: '' Stem: ''
# Actual: A Stem: a
# Actual: Child Stem: child
# Actual: al Stem: al
# Actual: Confino Stem: confino
# Actual: '' Stem: ''
# Actual: '' Stem: ''
# Actual: by Stem: by
# Actual: Eric Stem: eric
# Actual: Lamet Stem: lamet
# Actual: . Stem: .
# Actual: A Stem: a
# Actual: wonderful Stem: wonder
# Actual: book Stem: book
# Actual: , Stem: ,
# Actual: but Stem: but
# Actual: there Stem: there
# Actual: are Stem: are
# Actual: snippets Stem: snippet
# ...

# %%
wordnet_lemmatizer = WordNetLemmatizer()

nltk_tokens = nltk.word_tokenize(text)


for w in nltk_tokens:

    print ("Actual: % s Lemma: % s" % (w, wordnet_lemmatizer.lemmatize(w)))
# Out:
# Streaming output truncated to the last 5000 lines.
# Actual: thing Lemma: thing
# Actual: ever Lemma: ever
# Actual: invented Lemma: invented
# Actual: ! Lemma: !
# Actual: P Lemma: P
# Actual: 823 Lemma: 823
# Actual: '' Lemma: ''
# Actual: Any Lemma: Any
# Actual: chance Lemma: chance
# Actual: to Lemma: to
# Actual: add Lemma: add
# Actual: a Lemma: a
# Actual: foreign Lemma: foreign
# Actual: dictionary Lemma: dictionary
# Actual: ? Lemma: ?
# Actual: Im Lemma: Im
# Actual: reading Lemma: reading
# Actual: `` Lemma: ``
# Actual: '' Lemma: ''
# Actual: A Lemma: A
# Actual: Child Lemma: Child
# Actual: al Lemma: al
# Actual: Confino Lemma: Confino
# Actual: '' Lemma: ''
# Actual: '' Lemma: ''
# Actual: by Lemma: by
# Actual: Eric Lemma: Eric
# Actual: Lamet Lemma: Lamet
# Actual: . Lemma: .
# Actual: A Lemma: A
# Actual: wonderful Lemma: wonderful
# Actual: book Lemma: book
# Actual: , Lemma: ,
# Actual: but Lemma: but
# Actual: there Lemma: there
# Actual: are Lemma: are
# ...

# %%
text = nltk.word_tokenize(text)

print(nltk.pos_tag(text))
# Out:
# [('FBPost', 'NNP'), ('Label', 'NNP'), ('0', 'CD'), ('Drug', 'NNP'), ('Runners', 'NNPS'), ('and', 'CC'), ('a', 'DT'), ('U.S', 'NNP'), ('.', '.'), ('Senator', 'NNP'), ('have', 'VBP'), ('something', 'NN'), ('to', 'TO'), ('do', 'VB'), ('with', 'IN'), ('the', 'DT'), ('Murder', 'NNP'), ('http', 'NN'), (':', ':'), ('//www.amazon.com/Circumstantial-Evidence-Getting-Florida-Bozarth-ebook/dp/B004FPZ452/ref=pd_rhf_p_t_1', 'JJ'), ('The', 'DT'), ('State', 'NNP'), ('Attorney', 'NNP'), ('Knows', 'NNP'), ('...', ':'), ('NOW', 'NNP'), ('So', 'NNP'), ('Will', 'NNP'), ('You', 'PRP'), ('.', '.'), ('GET', 'VB'), ('Ypur', 'NNP'), ('Copy', 'NNP'), ('TODAY', 'NNP'), ('O', 'NNP'), ('1', 'CD'), ("''", "''"), ('Heres', 'VBZ'), ('a', 'DT'), ('single', 'JJ'), (',', ','), ('to', 'TO'), ('add', 'VB'), (',', ','), ('to', 'TO'), ('Kindle', 'NNP'), ('.', '.'), ('Just', 'NNP'), ('read', 'VBD'), ('this', 'DT'), ('19th', 'JJ'), ('century', 'NN'), ('story', 'NN'), (':', ':'), ('``', '``'), ("''", "''"), ('The', 'DT'), ('
# ...

# %%
sid = SentimentIntensityAnalyzer()

tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')


with open('kindle.txt', encoding ='ISO-8859-2') as f:
    compound_scores=[]
    pos_word_list=[]
    neu_word_list=[]
    neg_word_list=[]
    positive=[]
    negative=[]
    neutral=[]
    compound=[]
    for text in f.read().split('\n'):


        split_text = text.split() #split into list
        cleaned = []
        trans = str.maketrans('', '', string.punctuation)
        for word in split_text:
             x = word.translate(trans)
             cleaned.append(x)
        for word in cleaned:
             if (sid.polarity_scores(word)['compound']) >= 0.5:
                 pos_word_list.append(word)
             elif (sid.polarity_scores(word)['compound']) <= -0.5:
                 neg_word_list.append(word)
             else:
                 neu_word_list.append(word)
        print(text)

        scores = sid.polarity_scores(text)
        compound_scores.append(scores['compound'])
        negative.append(scores['neg'])
        neutral.append(scores['neu'])
        positive.append(scores['pos'])
        for key in sorted(scores):

            print('{0}: {1}, '.format(key, scores[key]), end ='')




    print()
    print(compound_scores)
# Out:
# 	FBPost	Label
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, 0	Drug Runners and  a U.S. Senator have something to do with the Murder http://www.amazon.com/Circumstantial-Evidence-Getting-Florida-Bozarth-ebook/dp/B004FPZ452/ref=pd_rhf_p_t_1 The State Attorney Knows... NOW So Will You. GET Ypur Copy TODAY	O
# compound: -0.6908, neg: 0.164, neu: 0.836, pos: 0.0, 1	"Heres a single, to add, to Kindle. Just read this 19th century story: ""The Ghost of Round Island"". Its about a man (French/American Indian) and his dog sled transporting a woman across the ice, from Mackinac Island to Cheboygan - and the ghost that..."	O
# compound: -0.5574, neg: 0.108, neu: 0.892, pos: 0.0, 2	If you tire of Non-Fiction.. Check out http://www.amazon.com/s/ref=nb_sb_noss?url=search-alias%3Daps&field-keywords=danielle+lee+zwissler+&x=0&y=0	O
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0, 3	Ghost of Round Island is supposedly nonfiction.	O
# ...

# %%
pos_word_list
# Out:
# ['love',
#  'awesome',
#  'great',
#  'love',
#  'loves',
#  'love',
#  'fun',
#  'Love',
#  'Best',
#  'love',
#  'FREE',
#  'Love',
#  'loving',
#  'LOVE',
#  'perfect',
#  'love',
#  'free',
#  'free',
#  'love',
#  'fun',
#  'love',
#  'Love',
#  'love',
#  'fun',
#  'Love',
#  'LOVE',
#  'LOVE',
#  'love',
#  'Best',
#  'love',
#  'love',
#  'prized',
#  'Beloved',
#  'awesome',
#  'love',
#  'LOVE',
#  'LOVE',
#  'awesome',
#  'love',
#  'Love',
#  'great',
#  'love',
#  'Love',
#  'beautiful',
#  'best',
#  'love',
#  'love',
#  'AWESOME',
#  'wonderful',
#  'love',
#  'happy',
#  'love',
#  'love',
#  'love',
#  'loved',
#  'love',
#  'best',
#  'Love',
#  'Best',
#  'LOVE',
#  'love',
#  'Love',
#  'love',
#  'love',
#  'wonderful',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'love',
#  'free',
#  'Love',
#  'love',
#  'love',
#  'Awesome',
#  'love',
#  'love',
#  'Best',
#  'lovingly',
#  'love',
#  'BEST',
#  'love',
#  'Yay',
# ...

# %%
pos_word_data= pd.DataFrame(pos_word_list,columns=['positive'])
pos_word_data['positive']=pos_word_data['positive'].apply(lambda x : x.lower())

# %%
positive_word = pos_word_data.value_counts().reset_index().rename(columns={"index": "value", 0: "count"})
positive_word
# Out:
#        positive  count
# 0          love    378
# 1         great     75
# 2          free     67
# 3          best     50
# 4       awesome     18
# 5         happy      8
# 6       perfect      8
# 7     wonderful      7
# 8        loving      6
# 9         loved      6
# 10          fun      6
# 11          wow      5
# 12    excellent      3
# 13        loves      3
# 14         kind      3
# 15        adore      3
# 16          yay      3
# 17     enjoying      3
# 18    brilliant      3
# 19          won      2
# 20          joy      2
# 21        trust      2
# 22    beautiful      2
# 23      amazing      2
# 24      enjoyed      2
# 25    fantastic      2
# 26  appreciated      1
# 27       wisdom      1
# 28          win      1
# 29     lovingly      1
# 30     superior      1
# 31         sexy      1
# 32       prized      1
# 33     positive      1
# 34     pleasure      1
# 35    perfectly      1
# 36   sweetheart      1
# 37        bonus      1
# 38      beloved      1
# ...

# %%
neu_word_list
# Out:
# ['FBPost',
#  'Label',
#  '0',
#  'Drug',
#  'Runners',
#  'and',
#  'a',
#  'US',
#  'Senator',
#  'have',
#  'something',
#  'to',
#  'do',
#  'with',
#  'the',
#  'httpwwwamazoncomCircumstantialEvidenceGettingFloridaBozarthebookdpB004FPZ452refpdrhfpt1',
#  'The',
#  'State',
#  'Attorney',
#  'Knows',
#  'NOW',
#  'So',
#  'Will',
#  'You',
#  'GET',
#  'Ypur',
#  'Copy',
#  'TODAY',
#  'O',
#  '1',
#  'Heres',
#  'a',
#  'single',
#  'to',
#  'add',
#  'to',
#  'Kindle',
#  'Just',
#  'read',
#  'this',
#  '19th',
#  'century',
#  'story',
#  'The',
#  'Ghost',
#  'of',
#  'Round',
#  'Island',
#  'Its',
#  'about',
#  'a',
#  'man',
#  'FrenchAmerican',
#  'Indian',
#  'and',
#  'his',
#  'dog',
#  'sled',
#  'transporting',
#  'a',
#  'woman',
#  'across',
#  'the',
#  'ice',
#  'from',
#  'Mackinac',
#  'Island',
#  'to',
#  'Cheboygan',
#  '',
#  'and',
#  'the',
#  'ghost',
#  'that',
#  'O',
#  '2',
#  'If',
#  'you',
#  'tire',
#  'of',
#  'NonFiction',
#  'Check',
# ...

# %% [markdown]
# data visualization

# %%
dist_of_senti={'Compound':compound_scores}

# %%
def splitting(a):
  if a >= 0.05 :
    return 'Positive'
  elif a <= -0.05 :
    return  'Negative'
  else :
    return 'Neutral'

# %%
dv_1=pd.DataFrame(dist_of_senti)

# %%
dv_1['Classification']=dv_1['Compound'].apply(splitting)
dv_1
# Out:
#       Compound Classification
# 0       0.0000        Neutral
# 1      -0.6908       Negative
# 2      -0.5574       Negative
# 3       0.0000        Neutral
# 4      -0.3182       Negative
# ...        ...            ...
# 1000    0.5994       Positive
# 1001    0.6015       Positive
# 1002    0.5175       Positive
# 1003    0.8268       Positive
# 1004    0.0000        Neutral
#
# [1005 rows x 2 columns]

# %%
dv_1['Classification'].value_counts()
# Out:
# Positive    721
# Neutral     179
# Negative    105
# Name: Classification, dtype: int64

# %%
dv_1['Classification'].unique()
# Out:
# array(['Neutral', 'Negative', 'Positive'], dtype=object)

# %%
plt.figure(figsize=(10, 6))
plt.bar(['Positive','Neutral','Negative'], dv_1['Classification'].value_counts())
plt.xlabel('Facebook sentiment analysis')
plt.ylabel('count')
plt.title('Count of Facebook Sentiment')
for i in range(len(dv_1['Classification'].unique())):
    plt.text(i, dv_1['Classification'].value_counts()[i], dv_1['Classification'].value_counts()[i])
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(positive_word['positive'][0:10],positive_word['count'][0:10] )
plt.xticks(rotation=90, ha='right')
plt.xlabel('positivereason')
plt.ylabel('Count')
plt.show()

# %%
neg_word_data= pd.DataFrame(neg_word_list,columns=['negative'])
neg_word_data['negative']=neg_word_data['negative'].apply(lambda x : x.lower())

# %%
negative_word = neg_word_data.value_counts().reset_index().rename(columns={"index": "value", 0: "count"})
negative_word
# Out:
#       negative  count
# 0          bad      7
# 1      poverty      6
# 2         sick      5
# 3           dx      4
# 4         pain      3
# 5         hate      3
# 6         hurt      3
# 7         ugly      2
# 8       stupid      2
# 9     stricken      2
# 10    negative      2
# 11      killer      1
# 12        ruin      1
# 13      murder      1
# 14     killing      1
# 15     killers      1
# 16         182      1
# 17     idiotic      1
# 18         187      1
# 19        hell      1
# 20        fail      1
# 21        dumb      1
# 22  disgusting      1
# 23         die      1
# 24        dead      1
# 25       curse      1
# 26       crime      1
# 27       angry      1
# 28    horrible      1

# %%
plt.figure(figsize=(10, 6))
plt.bar(negative_word['negative'][0:10],negative_word['count'][0:10] )
plt.xticks(rotation=90, ha='right')
plt.xlabel('negativereason')
plt.ylabel('Count')
plt.show()

# %%
neu_word_data= pd.DataFrame(neu_word_list,columns=['neutral'])
neu_word_data['neutral']=neu_word_data['neutral'].apply(lambda x : x.lower())

# %%
neutral_word = neu_word_data.value_counts().reset_index().rename(columns={"index": "value", 0: "count"})
neutral_word
# Out:
#          neutral  count
# 0              i   1038
# 1            the    904
# 2             to    644
# 3              p    643
# 4         kindle    622
# ...          ...    ...
# 3904        bomb      1
# 3905        bone      1
# 3906         boo      1
# 3907  bookmarked      1
# 3908     ăşltimo      1
#
# [3909 rows x 2 columns]

# %%
plt.figure(figsize=(10, 6))
plt.bar(neutral_word['neutral'][0:10],neutral_word['count'][0:10] )
plt.xticks(rotation=90, ha='right')
plt.xlabel('neutralreason')
plt.ylabel('Count')
plt.show()

# %%
df={'compound':compound_scores,'negative':negative ,'neutral':neutral ,'positive':positive}

# %%
df_1=pd.DataFrame(df)
df_1
# Out:
#       compound  negative  neutral  positive
# 0       0.0000     0.000    1.000     0.000
# 1      -0.6908     0.164    0.836     0.000
# 2      -0.5574     0.108    0.892     0.000
# 3       0.0000     0.000    1.000     0.000
# 4      -0.3182     0.277    0.723     0.000
# ...        ...       ...      ...       ...
# 1000    0.5994     0.050    0.829     0.121
# 1001    0.6015     0.143    0.514     0.344
# 1002    0.5175     0.147    0.552     0.302
# 1003    0.8268     0.000    0.281     0.719
# 1004    0.0000     0.000    0.000     0.000
#
# [1005 rows x 4 columns]

# %%
newdf = df_1.drop("compound", axis='columns')
newdf
# Out:
#       negative  neutral  positive
# 0        0.000    1.000     0.000
# 1        0.164    0.836     0.000
# 2        0.108    0.892     0.000
# 3        0.000    1.000     0.000
# 4        0.277    0.723     0.000
# ...        ...      ...       ...
# 1000     0.050    0.829     0.121
# 1001     0.143    0.514     0.344
# 1002     0.147    0.552     0.302
# 1003     0.000    0.281     0.719
# 1004     0.000    0.000     0.000
#
# [1005 rows x 3 columns]

# %%
import seaborn as sns

sns.kdeplot(data=newdf, fill=True, alpha=0.5)
# Out:
# <Axes: ylabel='Density'>

# %%
import random
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pandas as pd

random.seed(1234)

# Assuming 'd' is a pandas DataFrame with columns 'word' and 'freq'
words = positive_word['positive']
freq = positive_word['count']

text1 = " ".join(title for title in positive_word['positive'])

# Creating word_cloud with text as argument in .generate() method

word_cloud1 = WordCloud(collocations = False, background_color = 'white',
                        width = 2048, height = 1080).generate(text1)
# saving the image
word_cloud1.to_file('got.png')
plt.figure(figsize=(10, 8))
plt.imshow(word_cloud1, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
text1 = " ".join(title for title in negative_word['negative'])

# Creating word_cloud with text as argument in .generate() method

word_cloud1 = WordCloud(collocations = False, background_color = 'white',
                        width = 2048, height = 1080).generate(text1)
# saving the image
word_cloud1.to_file('got.png')
plt.figure(figsize=(10, 8))
plt.imshow(word_cloud1, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
text1 = " ".join(title for title in neutral_word['neutral'])

# Creating word_cloud with text as argument in .generate() method

word_cloud1 = WordCloud(collocations = False, background_color = 'white',
                        width = 2048, height = 1080).generate(text1)
# saving the image
word_cloud1.to_file('got.png')
plt.figure(figsize=(10, 8))
plt.imshow(word_cloud1, interpolation='bilinear')
plt.axis('off')
plt.show()
